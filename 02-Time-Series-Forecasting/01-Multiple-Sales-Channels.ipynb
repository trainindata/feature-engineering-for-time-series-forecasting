# %% [markdown]
# # Figures for slides
#
# This notebook creates figures that are used in the slides.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sales - Multiple channels

# %%
data = pd.read_csv('../Datasets/online_retail_dataset.csv')

data.head()
# Out:
#          week  Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# 0  2009-12-06      196.1      NaN      NaN    439.1     NaN     NaN
# 1  2009-12-13        0.0  1429.83      NaN      8.5     NaN     NaN
# 2  2009-12-20       75.0     0.00      NaN      0.0     NaN     NaN
# 3  2009-12-27        0.0   568.51      NaN      0.0     NaN     NaN
# 4  2010-01-03        0.0     0.00      NaN      0.0     NaN     NaN
#
#    Channel Islands   Cyprus  Czech Republic  ...  Singapore    Spain  Sweden  \
# 0           989.18   760.69             NaN  ...        NaN   435.88     NaN
# 1             0.00     0.00             NaN  ...        NaN   412.60   285.3
# 2             0.00  2796.29             NaN  ...        NaN  1952.64     0.0
# 3             0.00     0.00             NaN  ...        NaN  5149.06     0.0
# 4             0.00     0.00             NaN  ...        NaN     0.00     0.0
#
#    Switzerland  Thailand    USA  United Arab Emirates  United Kingdom  \
# ...

# %%
data.columns
# Out:
# Index(['week', 'Australia', 'Austria', 'Bahrain', 'Belgium', 'Brazil',
#        'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#        'EIRE', 'European Community', 'Finland', 'France', 'Germany', 'Greece',
#        'Iceland', 'Israel', 'Italy', 'Japan', 'Korea', 'Lebanon', 'Lithuania',
#        'Malta', 'Netherlands', 'Nigeria', 'Norway', 'Poland', 'Portugal',
#        'RSA', 'Saudi Arabia', 'Singapore', 'Spain', 'Sweden', 'Switzerland',
#        'Thailand', 'USA', 'United Arab Emirates', 'United Kingdom',
#        'Unspecified', 'West Indies'],
#       dtype='object')

# %%
plt.rc('font', size=15) # controls default text size

# %%
lands = ['Australia', 'Spain', 'Belgium', 'United Kingdom']

data.index = data['week']

data[lands].plot(figsize=(14, 6))
plt.ylabel('Revenue')
plt.xlabel('')
plt.title('Sales Revenue')
# Out:
# Text(0.5, 1.0, 'Sales Revenue')

# %% [markdown]
# ## Air Quality

# %%
filename = '../datasets/AirQualityUCI_ready.csv'

data = pd.read_csv(filename)

data.head()
# Out:
#              Date_Time  CO_true  CO_sensor  NMHC_true  C6H6_true  NMHC_sensor  \
# 0  2004-10-03 18:00:00      2.6     1360.0      150.0       11.9       1046.0
# 1  2004-10-03 19:00:00      2.0     1292.0      112.0        9.4        955.0
# 2  2004-10-03 20:00:00      2.2     1402.0       88.0        9.0        939.0
# 3  2004-10-03 21:00:00      2.2     1376.0       80.0        9.2        948.0
# 4  2004-10-03 22:00:00      1.6     1272.0       51.0        6.5        836.0
#
#    NOX_true  NOX_sensor  NO2_true  NO2_sensor  O3_sensor     T    RH      AH
# 0     166.0      1056.0     113.0      1692.0     1268.0  13.6  48.9  0.7578
# 1     103.0      1174.0      92.0      1559.0      972.0  13.3  47.7  0.7255
# 2     131.0      1140.0     114.0      1555.0     1074.0  11.9  54.0  0.7502
# 3     172.0      1092.0     122.0      1584.0     1203.0  11.0  60.0  0.7867
# 4     131.0      1205.0     116.0      1490.0     1110.0  11.2  59.6  0.7888

# %%
data['Date_Time'] = pd.to_datetime(data['Date_Time'])

data['Date'] = data['Date_Time'].dt.date
data['Time'] = data['Date_Time'].dt.time

data.head()
# Out:
#             Date_Time  CO_true  CO_sensor  NMHC_true  C6H6_true  NMHC_sensor  \
# 0 2004-10-03 18:00:00      2.6     1360.0      150.0       11.9       1046.0
# 1 2004-10-03 19:00:00      2.0     1292.0      112.0        9.4        955.0
# 2 2004-10-03 20:00:00      2.2     1402.0       88.0        9.0        939.0
# 3 2004-10-03 21:00:00      2.2     1376.0       80.0        9.2        948.0
# 4 2004-10-03 22:00:00      1.6     1272.0       51.0        6.5        836.0
#
#    NOX_true  NOX_sensor  NO2_true  NO2_sensor  O3_sensor     T    RH      AH  \
# 0     166.0      1056.0     113.0      1692.0     1268.0  13.6  48.9  0.7578
# 1     103.0      1174.0      92.0      1559.0      972.0  13.3  47.7  0.7255
# 2     131.0      1140.0     114.0      1555.0     1074.0  11.9  54.0  0.7502
# 3     172.0      1092.0     122.0      1584.0     1203.0  11.0  60.0  0.7867
# 4     131.0      1205.0     116.0      1490.0     1110.0  11.2  59.6  0.7888
#
#          Date      Time
# ...

# %%
# shorten time span to make simpler figures

data = data[data['Date_Time'] < '2005-01-01']

# %%
plot_vars = ['T', 'RH']

data.groupby('Date')[plot_vars].mean().plot(figsize=(10, 4))
plt.ylabel('Value - Concentration')
plt.xlabel('')
plt.title('Daily Temperature and Humidity')
# Out:
# Text(0.5, 1.0, 'Daily Temperature and Humidity')

# %%
data.groupby('Date_Time')[plot_vars].mean().plot(figsize=(10, 4))
plt.ylabel('Value - Concentration')
plt.xlabel('')
plt.title('Hourly Temperature and Humidity')
# Out:
# Text(0.5, 1.0, 'Hourly Temperature and Humidity')
